# %%
import numpy as np

# %%
# Create 1D array
a = np.array([5,6,9])
a[1]
# Out:
# 6

# %%
#creating 2-D array
a=np.array([[1,2],[3,4],[5,6]])
print(a)
a.ndim
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# 2

# %%
#print bytesize of elements
a.itemsize #because integers hence prints 8bytes
# Out:
# 8

# %%
a.dtype #says int64
# Out:
# dtype('int64')

# %%
a.size #no. of elements
# Out:
# 6

# %%
a.shape #rows * columns
# Out:
# (3, 2)

# %%
#create array of all zeros
np.zeros((2,3))  #just mention the shape of array
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
#create array of all ones
np.ones((2,3))  #just mention the shape of array
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
#range() creates a list of numbers
l = range(5)
l[3]
# Out:
# 3

# %%
l
# Out:
# range(0, 5)

# %%
##create an array
np.arange(1,5) #endlimit excluded
# Out:
# array([1, 2, 3, 4])

# %%
np.arange(1,5,2) #here 2 is step
# Out:
# array([1, 3])

# %%
#create an array of linearly spaced elements 
np.linspace(1,5,10)  #10 elemnets between 1 to 5
# Out:
# array([1.        , 1.44444444, 1.88888889, 2.33333333, 2.77777778,
#        3.22222222, 3.66666667, 4.11111111, 4.55555556, 5.        ])

# %%
np.linspace(1,10,5)
# Out:
# array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ])

# %%
#reshape
a.reshape(3,2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
a.reshape(1,6)
# Out:
# array([[1, 2, 3, 4, 5, 6]])

# %%
#flatten your array and make it 1D
a.ravel()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
a.min() #max(), sum() try
# Out:
# 1

# %%
#sum of all elements in 1st row  
a.sum(axis=1)  #row = 1, column =0
# Out:
# array([ 3,  7, 11])

# %%
np.sqrt(a)
# Out:
# array([[1.        , 1.41421356],
#        [1.73205081, 2.        ],
#        [2.23606798, 2.44948974]])

# %%
np.std(a) #standard deviation
# Out:
# 1.707825127659933

# %%
a = np.array([[1,2],[3,4]])
b = np.array([[5,6],[7,8]])

# %%
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
b
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
a+b
# Out:
# array([[ 6,  8],
#        [10, 12]])

# %%
a/b
# Out:
# array([[0.2       , 0.33333333],
#        [0.42857143, 0.5       ]])

# %%
a.dot(b)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
a*b
# Out:
# array([[ 5, 12],
#        [21, 32]])
