# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("bitcoin_dataset.csv")
df.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
df['btc_market_price'][1023]
# Out:
# 13.6888

# %%
df.corr()  #btc_market_cap has the closest correlation to output variable btc_market_price
# Out:
#                                                            -0.030112
# btc_avg_block_size                                                         -0.036717
# btc_n_orphaned_blocks                                                      -0.015803
# btc_n_transactions_per_block                                               -0.036007
# btc_median_confirmation_time                                               -0.055222
# btc_hash_rate                                                              -0.015868
# btc_difficulty                                                             -0.016129
# btc_miners_revenue                                                         -0.014251
# btc_transaction_fees                                                       -0.019066
# btc_cost_per_transaction_percent                                            1.000000
# btc_cost_per_transaction                                                   -0.025573
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['btc_total_bitcoins'].fillna(value=df['btc_total_bitcoins'].mean(), inplace=True)
